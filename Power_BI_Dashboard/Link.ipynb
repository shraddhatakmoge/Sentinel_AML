# %%
# Due to size issues , github coudn't save .pbix file 
# so just copy and paste this in URL

https://app.powerbi.com/groups/me/reports/41f8ca0e-fe3d-4695-9e3a-f19112b6e6a8/ca980e3b51aa8c91dbb2?experience=power-bi&bookmarkGuid=37d8a3ac68a4e5f37e3f
